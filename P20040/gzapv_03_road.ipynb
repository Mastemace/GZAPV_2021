# %% [markdown]
# <a href="https://colab.research.google.com/github/Mastemace/GZAPV_2021/blob/main/P20040/gzapv_03_road.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('road.jpg')
out = cv.Canny(img, 250, 255)
plt.subplot(1,2,1)
plt.imshow(out)
lines = cv.HoughLinesP(out, 1, np.pi/180, 320, minLineLength=150, maxLineGap=190)

for line in lines:
  x1,y1,x2,y2 = line[0]
  cv.line(img, (x1,y1), (x2, y2), (0,255,0),3)

plt.subplot(1,2,2)
plt.imshow(img)
cv.imwrite('out.jpg', img)
# Out:
# True
